# %%
import os
from datetime import datetime
import pandas as pd

# %% [markdown]
# # Parameters

# %%
# Parameters dictionary.
pm = {
    'organization': 'Google Inc',
    'start_date_train': datetime(2022,1,1),
    'end_date_train': datetime(2022,11,1),
    'start_date_test': datetime(2022,11,1),
    'end_date_test': datetime(2023,1,1),
    'n_articles': 5,
    'text_columns': [ 'abstract', 'lead_paragraph', 'snippet', 'headline.main', ],
}

# %% [markdown]
# ⭕ **Possible Improvements:**
#
# * The date range for the market data (dependent variable) could be larger than the date range for the news, since there may be a time lag.
# * Test for a number of years.
# * Play with what text columns are included or not.
# * Test if weighting articles by how much a company is mentioned in the article improves predictions.
# * Inspect how the number of articles published changes things.

# %% [markdown]
# # NYTimes Data

# %% [markdown]
# ## Retrieve Data
# To access the NYTimes API we will by using the `pynytimes` repository, for which the bibtex citations is:
# ```
# @software{Den_Heijer_pynytimes_2023,
#     author = {Den Heijer, Micha},
#     license = {MIT},
#     title = {{pynytimes}},
#     url = {https://github.com/michadenheijer/pynytimes},
#     version = {0.10.0},
#     year = {2023},
#     doi = {10.5281/zenodo.7821090}
# }
# ```
#
# Our API key is stored int the environment variable `NYTIMES_KEY`, which is set in e.g. `~/.bash_profile` or `~/.zshrc`

# %%
from pynytimes import NYTAPI
from my_api_info import get_nytimes_key

# %%
nytapi = NYTAPI(get_nytimes_key(), parse_dates=True )

# %%
results = nytapi.article_search(
    query=pm['organization'],
    results=pm['n_articles'],
    dates={ 'begin':pm['start_date_train'], 'end':pm['end_date_train'] }
)

# %% [markdown]
# ⭕ **Possible Improvement:**
#
# Currently searching with keywords. An advanced option is to use the filter query feature of the NYTimes API, e.g.
# ```
# options={
#     'fq': 'organizations:("Google Inc")',
# },
# ```
# This requires also filtering on the "rank" of the organization in regards to the article, as found in e.g. `article['keywords']['rank']`. Otherwise we'll get articles tangentially related to the target company.

# %% [markdown]
# ## Format Data

# %%
# Create storage dictionary
nyt_data = {
    'pub_date': [],
}
for column in pm['text_columns']:
    nyt_data[column] = []

# %%
# Collect
for i, result in enumerate( results ):
    for column in nyt_data.keys():
        
        # Parse column
        if '.' in column:
            column_keys = column.split( '.' )
            column_val = result[column_keys[0]][column_keys[1]]
        else:
            column_val = result[column]
            
        # Store
        nyt_data[column].append( column_val )

# %%
# Turn into a dataframe
nyt = pd.DataFrame( nyt_data )

# %%
# Collect the full string
nyt['text'] = ( nyt[pm['text_columns']] + ' ' ).sum( axis=1 )

# %%
nyt.head()
# Out:
#                    pub_date  \
# 0 2022-10-25 20:37:03+00:00
# 1 2022-10-26 22:47:44+00:00
# 2 2022-10-20 15:05:58+00:00
# 3 2022-10-28 12:06:38+00:00
# 4 2022-10-25 18:24:56+00:00
#
#                                             abstract  \
# 0  Google’s parent company reported earnings that...
# 1  A series of quarterly earnings reports is show...
# 2  Ken Paxton, the state attorney general, said p...
# 3  The social network’s new owner has just a few ...
# 4  Apple has rejected Spotify’s new app three tim...
#
#                                       lead_paragraph  \
# 0  Even Alphabet, the parent company of Google an...
# 1  Google this week reported a steep decline in p...
# 2  The Texas attorney general filed a privacy law...
# 3  Elon Musk closes his purchase of Twitter and f...
# 4  Daniel Ek, the chief executive of Spotify, wan...
#
#                                              snippet  \
# 0  Google’s parent company reported earnings that...
# 1  A series of quarterly earnings reports is show...
# 2  Ken Paxton, the state attorney general, said p...
# 3  The social network’s new owner has just a few ...
# 4  Apple has rejected Spotify’s new app three tim...
#
#                                        headline.main  \
# 0  Alphabet’s Profit Drops 27 Percent From a Year...
# 1  Tech’s Biggest Companies Are Sending Worrying ...
# 2  Texas Sues Google for Collecting Biometric Dat...
# 3    Elon Musk Faces Another Big Decision at Twitter
# 4  Spotify Wants to Get Into Audiobooks but Says ...
#
#                                                 text
# 0  Google’s parent company reported earnings that...
# 1  A series of quarterly earnings reports is show...
# 2  Ken Paxton, the state attorney general, said p...
# 3  The social network’s new owner has just a few ...
# 4  Apple has rejected Spotify’s new app three tim...

# %% [markdown]
# ## Sentiment Analysis
# Here, we are using textblob as our sentiment analysis tool. We are taking data from the text column of the data frame and outputting both polarity and subjectivity for each article. At the end, we are combining it into one single dataframe.

# %%
from textblob import TextBlob

# %%
pol_vec = []
subj_vec = []
for i in range (len(nyt['text'])):
    blob = TextBlob(nyt['text'][i])
    pol = blob.sentiment.polarity
    subj = blob.sentiment.subjectivity
    pol_vec.append(pol)
    subj_vec.append(subj)

# %%
d = {'Polarity': pol_vec, 'Subjectivity': subj_vec}
t = pd.DataFrame(data=d)

# %%
display(t)
# Out:
#    Polarity  Subjectivity
# 0  0.075000      0.410000
# 1  0.229167      0.558333
# 2  0.037500      0.375000
# 3  0.093939      0.274242
# 4  0.292532      0.487013
# 5  0.211310      0.342262
# 6  0.171429      0.565568
# 7 -0.068376      0.401709
# 8  0.355682      0.581818
# 9 -0.075385      0.182418

# %%
f = pd.concat([nyt,t], axis=1)

# %%
display(f)
# Out:
#                    pub_date  \
# 0 2022-10-25 20:37:03+00:00
# 1 2022-10-26 22:47:44+00:00
# 2 2022-10-20 15:05:58+00:00
# 3 2022-10-28 12:06:38+00:00
# 4 2022-10-25 18:24:56+00:00
# 5 2022-10-13 19:26:02+00:00
# 6 2022-10-12 17:00:18+00:00
# 7 2022-09-29 18:01:39+00:00
# 8 2022-09-28 17:25:57+00:00
# 9 2022-09-29 09:00:28+00:00
#
#                                             abstract  \
# 0  Google’s parent company reported earnings that...
# 1  A series of quarterly earnings reports is show...
# 2  Ken Paxton, the state attorney general, said p...
# 3  The social network’s new owner has just a few ...
# 4  Apple has rejected Spotify’s new app three tim...
# 5  Shares of the SPAC trying to merge with Donald...
# 6  Developed with Fitbit, Google’s first smart wa...
# 7  After nearly three years, Google has decided t...
# 8  From more photo-based results to neighborhood ...
# 9  Online, Iranians engage in a world their leade...
#
#                                       lead_paragraph  \
# 0  Even Alphabet, the parent company of Google an...
# 1  Google this week reported a steep decline in p...
# 2  The Texas attorney general filed a privacy law...
# 3  Elon Musk closes his purchase of Twitter and f...
# 4  Daniel Ek, the chief executive of Spotify, wan...
# 5  The shares of the cash-rich special purpose ac...
# 6  It’s 2022, and Google finally has a response t...
# 7  Google said it would shutter the video game st...
# 8  Google’s search engine looks a little differen...
# 9  In the physical world, Iran’s authoritarian le...
#
#                                              snippet  \
# 0  Google’s parent company reported earnings that...
# 1  A series of quarterly earnings reports is show...
# 2  Ken Paxton, the state attorney general, said p...
# 3  The social network’s new owner has just a few ...
# 4  Apple has rejected Spotify’s new app three tim...
# 5  Shares of the SPAC trying to merge with Donald...
# 6  Developed with Fitbit, Google’s first smart wa...
# 7  After nearly three years, Google has decided t...
# 8  From more photo-based results to neighborhood ...
# 9  Online, Iranians engage in a world their leade...
#
#                                        headline.main  \
# 0  Alphabet’s Profit Drops 27 Percent From a Year...
# 1  Tech’s Biggest Companies Are Sending Worrying ...
# 2  Texas Sues Google for Collecting Biometric Dat...
# 3    Elon Musk Faces Another Big Decision at Twitter
# 4  Spotify Wants to Get Into Audiobooks but Says ...
# 5  Google’s Move to Include Truth Social in App S...
# 6  The Google Watch Is Here. But You’d Better Lov...
# 7  Google to Shut Down Stadia Video Game Streamin...
# 8    Google to Make Search and Maps More ‘Immersive’
# 9  Despite Iran’s Efforts to Block Internet, Tech...
#
#                                                 text  Polarity  Subjectivity
# 0  Google’s parent company reported earnings that...  0.075000      0.410000
# 1  A series of quarterly earnings reports is show...  0.229167      0.558333
# 2  Ken Paxton, the state attorney general, said p...  0.037500      0.375000
# 3  The social network’s new owner has just a few ...  0.093939      0.274242
# 4  Apple has rejected Spotify’s new app three tim...  0.292532      0.487013
# 5  Shares of the SPAC trying to merge with Donald...  0.211310      0.342262
# 6  Developed with Fitbit, Google’s first smart wa...  0.171429      0.565568
# 7  After nearly three years, Google has decided t... -0.068376      0.401709
# 8  From more photo-based results to neighborhood ...  0.355682      0.581818
# 9  Online, Iranians engage in a world their leade... -0.075385      0.182418

# %% [markdown]
# ## Removing 'Irrelevant' Rows
# Some of the text columns don't mention google *enough* times. This portion of the notebook removes those rows.
#
# We need to import the library in the cell below in order to use the word_count function.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/michaelluo/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Counting instances of key words
#
# word_threshold is a hyperparameter for how many times 'google' is mentioned in the text, we can also add frequencies for additional/other key words based on the problem at hand. For example, doing research on another stock.

# %%
freq = blob.word_counts['google']
word_threshold = 1

# %%
for i in range (len(nyt['text'])):
    blob = TextBlob(nyt['text'][i])
    if blob.word_counts['google'] < word_threshold:
        f = f.drop(i)

# %%
display(f)
# Out:
#                    pub_date  \
# 0 2022-10-25 20:37:03+00:00
# 1 2022-10-26 22:47:44+00:00
# 2 2022-10-20 15:05:58+00:00
# 5 2022-10-13 19:26:02+00:00
# 6 2022-10-12 17:00:18+00:00
# 7 2022-09-29 18:01:39+00:00
# 8 2022-09-28 17:25:57+00:00
#
#                                             abstract  \
# 0  Google’s parent company reported earnings that...
# 1  A series of quarterly earnings reports is show...
# 2  Ken Paxton, the state attorney general, said p...
# 5  Shares of the SPAC trying to merge with Donald...
# 6  Developed with Fitbit, Google’s first smart wa...
# 7  After nearly three years, Google has decided t...
# 8  From more photo-based results to neighborhood ...
#
#                                       lead_paragraph  \
# 0  Even Alphabet, the parent company of Google an...
# 1  Google this week reported a steep decline in p...
# 2  The Texas attorney general filed a privacy law...
# 5  The shares of the cash-rich special purpose ac...
# 6  It’s 2022, and Google finally has a response t...
# 7  Google said it would shutter the video game st...
# 8  Google’s search engine looks a little differen...
#
#                                              snippet  \
# 0  Google’s parent company reported earnings that...
# 1  A series of quarterly earnings reports is show...
# 2  Ken Paxton, the state attorney general, said p...
# 5  Shares of the SPAC trying to merge with Donald...
# 6  Developed with Fitbit, Google’s first smart wa...
# 7  After nearly three years, Google has decided t...
# 8  From more photo-based results to neighborhood ...
#
#                                        headline.main  \
# 0  Alphabet’s Profit Drops 27 Percent From a Year...
# 1  Tech’s Biggest Companies Are Sending Worrying ...
# 2  Texas Sues Google for Collecting Biometric Dat...
# 5  Google’s Move to Include Truth Social in App S...
# 6  The Google Watch Is Here. But You’d Better Lov...
# 7  Google to Shut Down Stadia Video Game Streamin...
# 8    Google to Make Search and Maps More ‘Immersive’
#
#                                                 text  Polarity  Subjectivity
# 0  Google’s parent company reported earnings that...  0.075000      0.410000
# 1  A series of quarterly earnings reports is show...  0.229167      0.558333
# 2  Ken Paxton, the state attorney general, said p...  0.037500      0.375000
# 5  Shares of the SPAC trying to merge with Donald...  0.211310      0.342262
# 6  Developed with Fitbit, Google’s first smart wa...  0.171429      0.565568
# 7  After nearly three years, Google has decided t... -0.068376      0.401709
# 8  From more photo-based results to neighborhood ...  0.355682      0.581818
