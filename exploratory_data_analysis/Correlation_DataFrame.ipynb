# %%
#import packages
import pandas as pd
import numpy as np
import datetime
import seaborn as sns

# %%
#upload media.csv and markets.csv
media_data = pd.read_csv("../test_data/media.csv", index_col = 0, parse_dates = ['pub_date'])
markets_data = pd.read_csv("../test_data/markets.csv", parse_dates = ['Date'])
media_data.info()
markets_data.info() #unable to convert Date into datetime64 format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pub_date        100 non-null    datetime64[ns, UTC]
#  1   abstract        100 non-null    object
#  2   lead_paragraph  100 non-null    object
#  3   snippet         98 non-null     object
#  4   headline.main   100 non-null    object
#  5   text            100 non-null    object
#  6   Polarity        100 non-null    float64
#  7   Sentiment       100 non-null    float64
# dtypes: datetime64[ns, UTC](1), float64(2), object(5)
# memory usage: 7.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          209 non-null    object
#  1   Open          209 non-null    float64
#  2   High          209 non-null    float64
#  3   Low           209 non-null    float64
#  4   Close         209 non-null    float64
#  5   Volume        209 non-null    int64
#  6   Dividends     209 non-null    float64
#  7   Stock Splits  209 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 13.2+ KB

# %%
#top 5 rows of media_data
media_data.head()
# Out:
#                    pub_date  \
# 0 2022-10-25 20:37:03+00:00
# 1 2022-10-26 22:47:44+00:00
# 2 2022-10-20 15:05:58+00:00
# 3 2022-10-28 12:06:38+00:00
# 4 2022-10-25 18:24:56+00:00
#
#                                             abstract  \
# 0  Google’s parent company reported earnings that...
# 1  A series of quarterly earnings reports is show...
# 2  Ken Paxton, the state attorney general, said p...
# 3  The social network’s new owner has just a few ...
# 4  Apple has rejected Spotify’s new app three tim...
#
#                                       lead_paragraph  \
# 0  Even Alphabet, the parent company of Google an...
# 1  Google this week reported a steep decline in p...
# 2  The Texas attorney general filed a privacy law...
# 3  Elon Musk closes his purchase of Twitter and f...
# 4  Daniel Ek, the chief executive of Spotify, wan...
#
#                                              snippet  \
# 0  Google’s parent company reported earnings that...
# 1  A series of quarterly earnings reports is show...
# 2  Ken Paxton, the state attorney general, said p...
# 3  The social network’s new owner has just a few ...
# 4  Apple has rejected Spotify’s new app three tim...
#
#                                        headline.main  \
# 0  Alphabet’s Profit Drops 27 Percent From a Year...
# 1  Tech’s Biggest Companies Are Sending Worrying ...
# 2  Texas Sues Google for Collecting Biometric Dat...
# 3    Elon Musk Faces Another Big Decision at Twitter
# 4  Spotify Wants to Get Into Audiobooks but Says ...
#
#                                                 text  Polarity  Sentiment
# 0  Google’s parent company reported earnings that... -0.478889   0.504897
# 1  A series of quarterly earnings reports is show...  0.027064   0.979738
# 2  Ken Paxton, the state attorney general, said p... -0.880557   0.902320
# 3  The social network’s new owner has just a few ... -0.473785   0.693439
# 4  Apple has rejected Spotify’s new app three tim...  0.470216   0.492232

# %%
#top 5 rows of markets_data
markets_data.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2022-01-03 00:00:00-05:00  145.054993  145.850998  143.712997  144.991501
# 1  2022-01-04 00:00:00-05:00  145.395996  146.485001  143.716507  144.399506
# 2  2022-01-05 00:00:00-05:00  144.419998  144.499496  137.688004  137.774994
# 3  2022-01-06 00:00:00-05:00  136.998505  139.940002  136.558502  137.747498
# 4  2022-01-07 00:00:00-05:00  138.145493  138.448502  135.766495  137.016998
#
#      Volume  Dividends  Stock Splits
# 0  28646000        0.0           0.0
# 1  28400000        0.0           0.0
# 2  54618000        0.0           0.0
# 3  37348000        0.0           0.0
# 4  29760000        0.0           0.0

# %%
#changing the format of date and sorting the media_data by pub_date
media_data['pub_date'] = [date.strftime('%Y-%m-%d') for date in media_data['pub_date']]
markets_data['Date'] = [date.strftime('%Y-%m-%d') for date in markets_data['Date']]
media_data.sort_values(by='pub_date')
# Out:
#       pub_date                                           abstract  \
# 94  2022-01-06  The company will not be allowed to import prod...
# 91  2022-01-10  The latest tranche totals about 200. They are ...
# 86  2022-01-14  The states argue that Google reached a deal wi...
# 87  2022-01-14  The internet giant, planning on employees retu...
# 82  2022-01-20  Mustafa Suleyman, who played a key role in the...
# ..         ...                                                ...
# 2   2022-10-20  Ken Paxton, the state attorney general, said p...
# 4   2022-10-25  Apple has rejected Spotify’s new app three tim...
# 0   2022-10-25  Google’s parent company reported earnings that...
# 1   2022-10-26  A series of quarterly earnings reports is show...
# 3   2022-10-28  The social network’s new owner has just a few ...
#
#                                        lead_paragraph  \
# 94  OAKLAND, Calif. — Google infringed on five aud...
# 91  Google wrongly claimed attorney-client privile...
# 86  Google’s chief executive approved an agreement...
# 87  Google said Friday that it would spend $1 bill...
# 82  Mustafa Suleyman, a pioneer in the field of ar...
# ..                                                ...
# 2   The Texas attorney general filed a privacy law...
# 4   Daniel Ek, the chief executive of Spotify, wan...
# 0   Even Alphabet, the parent company of Google an...
# 1   Google this week reported a steep decline in p...
# 3   Elon Musk closes his purchase of Twitter and f...
#
#                                               snippet  \
# 94  The company will not be allowed to import prod...
# 91  The latest tranche totals about 200. They are ...
# 86  The states argue that Google reached a deal wi...
# 87  The internet giant, planning on employees retu...
# 82  Mustafa Suleyman, who played a key role in the...
# ..                                                ...
# 2   Ken Paxton, the state attorney general, said p...
# 4   Apple has rejected Spotify’s new app three tim...
# 0   Google’s parent company reported earnings that...
# 1   A series of quarterly earnings reports is show...
# 3   The social network’s new owner has just a few ...
#
#                                         headline.main  \
# 94  Google Infringed on Sonos Speaker Technology, ...
# 91  Google must turn over more documents in a labo...
# 86  Google’s chief executive signed off on deal at...
# 87  Google pays $1 billion for a London office bui...
# 82  DeepMind co-founder leaves Google after a rock...
# ..                                                ...
# 2   Texas Sues Google for Collecting Biometric Dat...
# 4   Spotify Wants to Get Into Audiobooks but Says ...
# 0   Alphabet’s Profit Drops 27 Percent From a Year...
# 1   Tech’s Biggest Companies Are Sending Worrying ...
# 3     Elon Musk Faces Another Big Decision at Twitter
#
#                                                  text  Polarity  Sentiment
# 94  The company will not be allowed to import prod... -0.679161   0.876380
# 91  The latest tranche totals about 200. They are ... -0.762656   0.638658
# 86  The states argue that Google reached a deal wi... -0.311683   0.634306
# 87  The internet giant, planning on employees retu... -0.488410   0.818022
# 82  Mustafa Suleyman, who played a key role in the...  0.812955   0.340731
# ..                                                ...       ...        ...
# 2   Ken Paxton, the state attorney general, said p... -0.880557   0.902320
# 4   Apple has rejected Spotify’s new app three tim...  0.470216   0.492232
# 0   Google’s parent company reported earnings that... -0.478889   0.504897
# 1   A series of quarterly earnings reports is show...  0.027064   0.979738
# 3   The social network’s new owner has just a few ... -0.473785   0.693439
#
# [100 rows x 8 columns]

# %%
#pub_date is in Year-Month-Day format
media_data.head()
# Out:
#      pub_date                                           abstract  \
# 0  2022-10-25  Google’s parent company reported earnings that...
# 1  2022-10-26  A series of quarterly earnings reports is show...
# 2  2022-10-20  Ken Paxton, the state attorney general, said p...
# 3  2022-10-28  The social network’s new owner has just a few ...
# 4  2022-10-25  Apple has rejected Spotify’s new app three tim...
#
#                                       lead_paragraph  \
# 0  Even Alphabet, the parent company of Google an...
# 1  Google this week reported a steep decline in p...
# 2  The Texas attorney general filed a privacy law...
# 3  Elon Musk closes his purchase of Twitter and f...
# 4  Daniel Ek, the chief executive of Spotify, wan...
#
#                                              snippet  \
# 0  Google’s parent company reported earnings that...
# 1  A series of quarterly earnings reports is show...
# 2  Ken Paxton, the state attorney general, said p...
# 3  The social network’s new owner has just a few ...
# 4  Apple has rejected Spotify’s new app three tim...
#
#                                        headline.main  \
# 0  Alphabet’s Profit Drops 27 Percent From a Year...
# 1  Tech’s Biggest Companies Are Sending Worrying ...
# 2  Texas Sues Google for Collecting Biometric Dat...
# 3    Elon Musk Faces Another Big Decision at Twitter
# 4  Spotify Wants to Get Into Audiobooks but Says ...
#
#                                                 text  Polarity  Sentiment
# 0  Google’s parent company reported earnings that... -0.478889   0.504897
# 1  A series of quarterly earnings reports is show...  0.027064   0.979738
# 2  Ken Paxton, the state attorney general, said p... -0.880557   0.902320
# 3  The social network’s new owner has just a few ... -0.473785   0.693439
# 4  Apple has rejected Spotify’s new app three tim...  0.470216   0.492232

# %%
#Date is in Year-Month-Day format
markets_data.tail(10)
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 199  2022-10-18  103.129997  103.470001   99.970001  100.769997  24060700
# 200  2022-10-19  100.010002  101.019997   98.919998   99.629997  23811100
# 201  2022-10-20  100.000000  102.320000   99.389999   99.970001  25323200
# 202  2022-10-21   97.849998  101.309998   97.720001  101.129997  32458700
# 203  2022-10-24  101.800003  102.750000   99.980003  102.519997  27176400
# 204  2022-10-25  102.900002  104.820000  102.720001  104.480003  40611400
# 205  2022-10-26   96.430000   98.309998   94.690002   94.930000  88114100
# 206  2022-10-27   94.519997   95.430000   91.800003   92.220001  60710900
# 207  2022-10-28   92.269997   96.550003   92.129997   96.290001  43697300
# 208  2022-10-31   95.419998   96.029999   93.980003   94.510002  31675000
#
#      Dividends  Stock Splits
# 199        0.0           0.0
# 200        0.0           0.0
# 201        0.0           0.0
# 202        0.0           0.0
# 203        0.0           0.0
# 204        0.0           0.0
# 205        0.0           0.0
# 206        0.0           0.0
# 207        0.0           0.0
# 208        0.0           0.0

# %%
media_data.info()
markets_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pub_date        100 non-null    object
#  1   abstract        100 non-null    object
#  2   lead_paragraph  100 non-null    object
#  3   snippet         98 non-null     object
#  4   headline.main   100 non-null    object
#  5   text            100 non-null    object
#  6   Polarity        100 non-null    float64
#  7   Sentiment       100 non-null    float64
# dtypes: float64(2), object(6)
# memory usage: 7.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          209 non-null    object
#  1   Open          209 non-null    float64
#  2   High          209 non-null    float64
#  3   Low           209 non-null    float64
#  4   Close         209 non-null    float64
#  5   Volume        209 non-null    int64
#  6   Dividends     209 non-null    float64
#  7   Stock Splits  209 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 13.2+ KB

# %%
# Set h
h = 4

# %%
# Looping through all days in 2022, recording average polarity, sentiment, closing stock price on that day
# and closing stock price on day + h (given it's NOT a weekend)

Date = []
Average_Polarity = []
Average_Sentiment = []
Close = []
Close_h = [] # Closing stock price after date + 4 days (given it's a not weekend)

start_date = datetime.date(2022, 1, 1)
end_date = datetime.date(2022, 10, 25)
delta = datetime.timedelta(days = 1)

while (start_date <= end_date):
    if str(start_date) not in media_data.pub_date.values:
        start_date += delta
        continue
        
    Date.append(str(start_date))
    Average_Polarity.append(media_data.Polarity.loc[media_data.pub_date == str(start_date)].mean())
    Average_Sentiment.append(media_data.Sentiment.loc[media_data.pub_date == str(start_date)].mean())
    
    date1 = start_date
    while str(date1) not in markets_data.Date.values:
        date1 -= delta 
    Close.append(markets_data['Close'].loc[markets_data.Date == str(date1)].item())
    
    date2 = start_date + h * delta
    while str(date2) not in markets_data.Date.values:
        date2 += delta 
    Close_h.append(markets_data['Close'].loc[markets_data.Date == str(date2)].item())
    
    start_date += delta

# %%
Correlation_df = pd.DataFrame({'Date' : Date, 'Average_Polarity' : Average_Polarity, 'Average_Sentiment' : Average_Sentiment,
                     'Close' : Close, 'Close_h' : Close_h})

# %%
Correlation_df['Change_in_Close'] = Correlation_df['Close_h'] - Correlation_df['Close']

# %%
print(Correlation_df)
# Out:
#           Date  Average_Polarity  Average_Sentiment       Close     Close_h  \
# 0   2022-01-06         -0.679161           0.876380  137.747498  138.669495
# 1   2022-01-10         -0.762656           0.638658  138.669495  139.480499
# 2   2022-01-14         -0.400046           0.726164  139.480499  135.998001
# 3   2022-01-20          0.812955           0.340731  133.307495  130.804001
# 4   2022-01-21         -0.007749           0.079756  130.351501  126.934998
# ..         ...               ...                ...         ...         ...
# 76  2022-09-29         -0.156881           0.876932   97.419998   98.639999
# 77  2022-10-12          0.910732           0.734579   97.559998   99.970001
# 78  2022-10-13         -0.824622           0.590450   99.059998   99.970001
# 79  2022-10-20         -0.880557           0.902320   99.970001  102.519997
# 80  2022-10-25         -0.004337           0.498565  104.480003   94.510002
#
#     Change_in_Close
# 0          0.921997
# 1          0.811005
# 2         -3.482498
# 3         -2.503494
# 4         -3.416504
# ..              ...
# 76         1.220001
# 77         2.410004
# 78         0.910004
# 79         2.549995
# 80        -9.970001
#
# [81 rows x 6 columns]

# %% [markdown]
# ## Visualize

# %%
sns.pairplot(
    Correlation_df,
    x_vars = [ 'Average_Polarity', ],
    y_vars = [ 'Change_in_Close', ],
    kind = 'reg',
)
